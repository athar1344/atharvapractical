# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
df10 = pd.read_csv(r"C:\Users\athar\OneDrive\Desktop\Practical\DSPrac\Datasets\Iris.csv")
df10
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df10.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df10.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
numeric_cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

scaler = MinMaxScaler()
df10[numeric_cols] = scaler.fit_transform(df10[numeric_cols])
df10[numeric_cols].head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       0.222222      0.625000       0.067797      0.041667
# 1       0.166667      0.416667       0.067797      0.041667
# 2       0.111111      0.500000       0.050847      0.041667
# 3       0.083333      0.458333       0.084746      0.041667
# 4       0.194444      0.666667       0.067797      0.041667

# %%
sns.histplot(x=df10['SepalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(x=df10['SepalWidthCm'],kde=True)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(x=df10['PetalLengthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(x=df10['PetalWidthCm'],kde=True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
sns.boxplot(data=df10['SepalLengthCm'])
plt.title("Boxplot of Sepal length")
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal length')

# %%
sns.boxplot(data=df10['SepalWidthCm'])
plt.title("Boxplot of Sepal Width")
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal Width')

# %%
sns.boxplot(data=df10['PetalLengthCm'])
plt.title("Boxplot of Petal length")
# Out:
# Text(0.5, 1.0, 'Boxplot of Petal length')

# %%
sns.boxplot(data=df10['PetalWidthCm'])
plt.title("Boxplot of Petal Width")
# Out:
# Text(0.5, 1.0, 'Boxplot of Petal Width')

# %%
sns.boxplot(data=df10)
plt.title("Boxplot of Features in the Iris Dataset", fontsize=14)
plt.show()

# %%
numeric_cols = df10.select_dtypes(include=np.number).columns
for col in numeric_cols:
    q1 = df10[col].quantile(0.25)
    q3 = df10[col].quantile(0.75)
    IQR = q3 - q1
    lower_bound = q1 - 1.5*IQR
    upper_bound = q3 + 1.5*IQR
    df10 = df10[(df10[col]>=lower_bound)&(df10[col]<=upper_bound)]

df10
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       0.222222      0.625000       0.067797      0.041667
# 1      2       0.166667      0.416667       0.067797      0.041667
# 2      3       0.111111      0.500000       0.050847      0.041667
# 3      4       0.083333      0.458333       0.084746      0.041667
# 4      5       0.194444      0.666667       0.067797      0.041667
# ..   ...            ...           ...            ...           ...
# 145  146       0.666667      0.416667       0.711864      0.916667
# 146  147       0.555556      0.208333       0.677966      0.750000
# 147  148       0.611111      0.416667       0.711864      0.791667
# 148  149       0.527778      0.583333       0.745763      0.916667
# 149  150       0.444444      0.416667       0.694915      0.708333
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.boxplot(data=df10)
plt.title("Boxplot of Features in the Iris Dataset", fontsize=14)
plt.show()
